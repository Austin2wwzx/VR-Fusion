# %%
import os
import os.path as osp
import json
import numpy as np

import matplotlib.pyplot as plt 
from radar_dataclass import *
from natsort import natsorted

# %%
RADAR_DATA_DIR = '../radar/json/'

radar_file_path_list = [osp.join(RADAR_DATA_DIR, path) for path in natsorted(os.listdir(RADAR_DATA_DIR)) if path.endswith('json')]

# %%
test_sample = radar_file_path_list[1]

# %%
with open(test_sample, 'r') as file:
    data_dict = json.load(file)

# %%
adc_data = adcStruct(**{keys: data_dict['adcStruct'][keys] for keys in data_dict['adcStruct']})

bv_data = beamVectorStruct(**{keys: data_dict['beamVectorStruct'][keys] for keys in data_dict['beamVectorStruct']})

tLVHeaders = [TLVHeader(**tlv) for tlv in data_dict['frameHeader']['tLVHeaderlsit']]
frame_data = frameHeader(**{key: data_dict['frameHeader'][key] for key in data_dict['frameHeader'] if key != 'tLVHeaderlsit'}, tLVHeaderlist=tLVHeaders)

hrrp_data = hrrpStruct(data_dict['hrrp'])

rd_data = rangeDopplerStruct(data_dict['rangeDoppler'])

ra_data = rangeAngleStruct(**{keys: data_dict['rangeAngle'][keys] for keys in data_dict['rangeAngle']})

det_data = detPointsStruct([detections(**item) for item in data_dict['detPoints']])

trk_data = trackStruct([tracks(**item) for item in data_dict['track']])

# %%
data_dict['detPoints']
# Out:
# [{'angle': 21.49340057373047,
#   'doppler': 28.265625,
#   'dopplerIdx': 312,
#   'peakVal': 4536.0,
#   'range': 9.703125,
#   'rangeIdx': 10,
#   'snr': 1098.0},
#  {'angle': 21.298091888427734,
#   'doppler': 28.25,
#   'dopplerIdx': 316,
#   'peakVal': 4374.0,
#   'range': 10.5,
#   'rangeIdx': 10,
#   'snr': 936.0},
#  {'angle': 21.474607467651367,
#   'doppler': 28.546875,
#   'dopplerIdx': 319,
#   'peakVal': 4398.0,
#   'range': 10.546875,
#   'rangeIdx': 10,
#   'snr': 954.0},
#  {'angle': 21.59867286682129,
#   'doppler': 28.96875,
#   'dopplerIdx': 322,
#   'peakVal': 4152.0,
#   'range': 10.4375,
#   'rangeIdx': 10,
#   'snr': 708.0},
#  {'angle': 21.51595115661621,
#   'doppler': 29.03125,
#   'dopplerIdx': 324,
#   'peakVal': 4248.0,
#   'range': 10.59375,
#   'rangeIdx': 10,
#   'snr': 810.0},
#  {'angle': -5.924072742462158,
#   'doppler': 29.5625,
#   'dopplerIdx': 329,
#   'peakVal': 4152.0,
#   'range': 10.625,
#   'rangeIdx': 10,
#   'snr': 708.0},
#  {'angle': -23.225326538085938,
#   'doppler': -28.109375,
#   'dopplerIdx': 69,
#   'peakVal': 4080.0,
#   'range': 61.46875,
#   'rangeIdx': 58,
#   'snr': 726.0},
#  {'angle': -16.677675247192383,
#   'doppler': -27.78125,
#   'dopplerIdx': 83,
#   'peakVal': 4170.0,
#   'range': 63.46875,
#   'rangeIdx': 61,
#   'snr': 780.0},
#  {'angle': 5.751823425292969,
#   'doppler': 25.96875,
#   'dopplerIdx': 328,
#   'peakVal': 4110.0,
#   'range': 112.640625,
#   'rangeIdx': 108,
#   'snr': 660.0},
#  {'angle': 5.769397735595703,
#   'doppler': 26.59375,
#   'dopplerIdx': 334,
#   'peakVal': 4218.0,
#   'range': 112.671875,
#   'rangeIdx': 108,
#   'snr': 762.0},
#  {'angle': 5.077375411987305,
#   'doppler': -28.265625,
#   'dopplerIdx': 340,
#   'peakVal': 4260.0,
#   'range': 112.5625,
#   'rangeIdx': 108,
#   'snr': 810.0},
#  {'angle': 5.741279602050781,
#   'doppler': -28.0,
#   'dopplerIdx': 345,
#   'peakVal': 4212.0,
#   'range': 112.9375,
#   'rangeIdx': 108,
#   'snr': 762.0},
#  {'angle': 5.934620380401611,
#   'doppler': 1.84375,
#   'dopplerIdx': 162,
#   'peakVal': 4002.0,
#   'range': 123.125,
#   'rangeIdx': 118,
#   'snr': 546.0},
#  {'angle': 6.085824966430664,
#   'doppler': 28.015625,
#   'dopplerIdx': 457,
#   'peakVal': 3984.0,
#   'range': 133.25,
#   'rangeIdx': 127,
#   'snr': 528.0},
#  {'angle': 5.495303630828857,
#   'doppler': -29.5625,
#   'dopplerIdx': 137,
#   'peakVal': 4236.0,
#   'range': 172.625,
#   'rangeIdx': 165,
#   'snr': 720.0},
#  {'angle': 6.261698246002197,
#   'doppler': -28.90625,
#   'dopplerIdx': 143,
#   'peakVal': 4230.0,
#   'range': 172.6875,
#   'rangeIdx': 165,
#   'snr': 714.0},
#  {'angle': 6.152649879455566,
#   'doppler': -28.53125,
#   'dopplerIdx': 146,
#   'peakVal': 4104.0,
#   'range': 172.640625,
#   'rangeIdx': 165,
#   'snr': 588.0},
#  {'angle': 6.008459568023682,
#   'doppler': -28.265625,
#   'dopplerIdx': 149,
#   'peakVal': 4368.0,
#   'range': 172.71875,
#   'rangeIdx': 165,
#   'snr': 852.0},
#  {'angle': 6.043623924255371,
#   'doppler': -28.21875,
#   'dopplerIdx': 153,
#   'peakVal': 4476.0,
#   'range': 173.40625,
#   'rangeIdx': 165,
#   'snr': 960.0},
#  {'angle': 5.945168495178223,
#   'doppler': -26.875,
#   'dopplerIdx': 163,
#   'peakVal': 4056.0,
#   'range': 173.015625,
#   'rangeIdx': 165,
#   'snr': 540.0},
#  {'angle': 5.825638294219971,
#   'doppler': -3.734375,
#   'dopplerIdx': 429,
#   'peakVal': 4296.0,
#   'range': 182.9375,
#   'rangeIdx': 175,
#   'snr': 738.0},
#  {'angle': 5.860791206359863,
#   'doppler': -1.875,
#   'dopplerIdx': 447,
#   'peakVal': 4488.0,
#   'range': 182.96875,
#   'rangeIdx': 175,
#   'snr': 930.0},
#  {'angle': 5.829153060913086,
#   'doppler': 1.734375,
#   'dopplerIdx': 481,
#   'peakVal': 4482.0,
#   'range': 183.25,
#   'rangeIdx': 175,
#   'snr': 924.0},
#  {'angle': 5.6991047859191895,
#   'doppler': 3.84375,
#   'dopplerIdx': 498,
#   'peakVal': 4404.0,
#   'range': 182.78125,
#   'rangeIdx': 175,
#   'snr': 846.0},
#  {'angle': 6.099892616271973,
#   'doppler': 28.140625,
#   'dopplerIdx': 263,
#   'peakVal': 4116.0,
#   'range': 192.796875,
#   'rangeIdx': 185,
#   'snr': 606.0},
#  {'angle': -0.6644557118415833,
#   'doppler': 27.921875,
#   'dopplerIdx': 404,
#   'peakVal': 3924.0,
#   'range': 219.5,
#   'rangeIdx': 210,
#   'snr': 564.0},
#  {'angle': -0.7763703465461731,
#   'doppler': -2.0,
#   'dopplerIdx': 185,
#   'peakVal': 4020.0,
#   'range': 230.046875,
#   'rangeIdx': 220,
#   'snr': 612.0},
#  {'angle': -0.8568108677864075,
#   'doppler': 1.859375,
#   'dopplerIdx': 220,
#   'peakVal': 4032.0,
#   'range': 229.984375,
#   'rangeIdx': 220,
#   'snr': 618.0},
#  {'angle': 14.82089614868164,
#   'doppler': 1.921875,
#   'dopplerIdx': 233,
#   'peakVal': 4026.0,
#   'range': 232.40625,
#   'rangeIdx': 222,
#   'snr': 600.0},
#  {'angle': 14.857071876525879,
#   'doppler': -2.171875,
#   'dopplerIdx': 199,
#   'peakVal': 3972.0,
#   'range': 233.046875,
#   'rangeIdx': 223,
#   'snr': 546.0},
#  {'angle': 5.92758846282959,
#   'doppler': -28.234375,
#   'dopplerIdx': 153,
#   'peakVal': 4080.0,
#   'range': 171.96875,
#   'rangeIdx': 164,
#   'snr': 666.0},
#  {'angle': 5.8994622230529785,
#   'doppler': -29.5625,
#   'dopplerIdx': 136,
#   'peakVal': 4230.0,
#   'range': 172.578125,
#   'rangeIdx': 165,
#   'snr': 714.0},
#  {'angle': 21.711551666259766,
#   'doppler': 28.265625,
#   'dopplerIdx': 313,
#   'peakVal': 4368.0,
#   'range': 9.59375,
#   'rangeIdx': 10,
#   'snr': 924.0},
#  {'angle': -23.084598541259766,
#   'doppler': -0.390625,
#   'dopplerIdx': 382,
#   'peakVal': 4332.0,
#   'range': 72.34375,
#   'rangeIdx': 68,
#   'snr': 876.0},
#  {'angle': -16.633872985839844,
#   'doppler': 0.96875,
#   'dopplerIdx': 393,
#   'peakVal': 4332.0,
#   'range': 72.171875,
#   'rangeIdx': 69,
#   'snr': 840.0},
#  {'angle': -16.703231811523438,
#   'doppler': 0.96875,
#   'dopplerIdx': 394,
#   'peakVal': 4572.0,
#   'range': 72.171875,
#   'rangeIdx': 69,
#   'snr': 1080.0},
#  {'angle': 5.969780445098877,
#   'doppler': -28.25,
#   'dopplerIdx': 152,
#   'peakVal': 4398.0,
#   'range': 173.4375,
#   'rangeIdx': 165,
#   'snr': 882.0},
#  {'angle': -16.72148895263672,
#   'doppler': 0.9375,
#   'dopplerIdx': 395,
#   'peakVal': 4266.0,
#   'range': 72.171875,
#   'rangeIdx': 69,
#   'snr': 780.0},
#  {'angle': 6.040107250213623,
#   'doppler': -28.1875,
#   'dopplerIdx': 154,
#   'peakVal': 4416.0,
#   'range': 173.453125,
#   'rangeIdx': 165,
#   'snr': 900.0},
#  {'angle': -23.31287956237793,
#   'doppler': -1.171875,
#   'dopplerIdx': 380,
#   'peakVal': 4332.0,
#   'range': 73.25,
#   'rangeIdx': 70,
#   'snr': 840.0},
#  {'angle': 5.656932830810547,
#   'doppler': -29.546875,
#   'dopplerIdx': 137,
#   'peakVal': 4170.0,
#   'range': 172.625,
#   'rangeIdx': 166,
#   'snr': 666.0},
#  {'angle': 6.117477893829346,
#   'doppler': -28.921875,
#   'dopplerIdx': 143,
#   'peakVal': 4176.0,
#   'range': 172.6875,
#   'rangeIdx': 166,
#   'snr': 672.0},
#  {'angle': 5.987361431121826,
#   'doppler': -28.265625,
#   'dopplerIdx': 149,
#   'peakVal': 4338.0,
#   'range': 172.703125,
#   'rangeIdx': 166,
#   'snr': 834.0},
#  {'angle': 5.987361431121826,
#   'doppler': -28.25,
#   'dopplerIdx': 152,
#   'peakVal': 4344.0,
#   'range': 172.671875,
#   'rangeIdx': 166,
#   'snr': 840.0},
#  {'angle': 6.008459568023682,
#   'doppler': -28.21875,
#   'dopplerIdx': 153,
#   'peakVal': 4410.0,
#   'range': 172.65625,
#   'rangeIdx': 166,
#   'snr': 906.0},
#  {'angle': 6.019008636474609,
#   'doppler': -28.1875,
#   'dopplerIdx': 154,
#   'peakVal': 4356.0,
#   'range': 172.65625,
#   'rangeIdx': 166,
#   'snr': 852.0},
#  {'angle': 5.80454683303833,
#   'doppler': -1.828125,
#   'dopplerIdx': 447,
#   'peakVal': 4344.0,
#   'range': 182.8125,
#   'rangeIdx': 174,
#   'snr': 786.0},
#  {'angle': -16.670373916625977,
#   'doppler': -0.859375,
#   'dopplerIdx': 393,
#   'peakVal': 4614.0,
#   'range': 75.328125,
#   'rangeIdx': 72,
#   'snr': 1056.0},
#  {'angle': 5.934620380401611,
#   'doppler': -3.796875,
#   'dopplerIdx': 430,
#   'peakVal': 4254.0,
#   'range': 182.921875,
#   'rangeIdx': 175,
#   'snr': 696.0},
#  {'angle': 5.801032066345215,
#   'doppler': -1.875,
#   'dopplerIdx': 446,
#   'peakVal': 4458.0,
#   'range': 183.1875,
#   'rangeIdx': 175,
#   'snr': 900.0},
#  {'angle': -16.750701904296875,
#   'doppler': -0.84375,
#   'dopplerIdx': 394,
#   'peakVal': 4842.0,
#   'range': 75.328125,
#   'rangeIdx': 72,
#   'snr': 1284.0},
#  {'angle': 5.973296642303467,
#   'doppler': -1.84375,
#   'dopplerIdx': 448,
#   'peakVal': 4230.0,
#   'range': 182.859375,
#   'rangeIdx': 175,
#   'snr': 672.0},
#  {'angle': 5.670989990234375,
#   'doppler': 1.734375,
#   'dopplerIdx': 480,
#   'peakVal': 4218.0,
#   'range': 183.109375,
#   'rangeIdx': 175,
#   'snr': 660.0},
#  {'angle': 21.53850746154785,
#   'doppler': 28.28125,
#   'dopplerIdx': 312,
#   'peakVal': 4386.0,
#   'range': 10.46875,
#   'rangeIdx': 9,
#   'snr': 978.0},
#  {'angle': 5.969780445098877,
#   'doppler': 1.734375,
#   'dopplerIdx': 482,
#   'peakVal': 4434.0,
#   'range': 183.046875,
#   'rangeIdx': 175,
#   'snr': 876.0},
#  {'angle': 6.054173946380615,
#   'doppler': 1.796875,
#   'dopplerIdx': 483,
#   'peakVal': 4230.0,
#   'range': 182.953125,
#   'rangeIdx': 175,
#   'snr': 672.0},
#  {'angle': -5.477737903594971,
#   'doppler': 28.296875,
#   'dopplerIdx': 313,
#   'peakVal': 4320.0,
#   'range': 10.375,
#   'rangeIdx': 9,
#   'snr': 912.0},
#  {'angle': 5.955716133117676,
#   'doppler': 3.828125,
#   'dopplerIdx': 499,
#   'peakVal': 4356.0,
#   'range': 183.15625,
#   'rangeIdx': 175,
#   'snr': 798.0},
#  {'angle': 5.976812362670898,
#   'doppler': 1.734375,
#   'dopplerIdx': 481,
#   'peakVal': 4320.0,
#   'range': 183.234375,
#   'rangeIdx': 176,
#   'snr': 702.0},
#  {'angle': 21.286832809448242,
#   'doppler': 28.25,
#   'dopplerIdx': 316,
#   'peakVal': 4236.0,
#   'range': 10.53125,
#   'rangeIdx': 9,
#   'snr': 828.0},
#  {'angle': 21.335630416870117,
#   'doppler': 28.546875,
#   'dopplerIdx': 319,
#   'peakVal': 4230.0,
#   'range': 10.546875,
#   'rangeIdx': 9,
#   'snr': 822.0},
#  {'angle': 4.14412784576416,
#   'doppler': 55.0,
#   'dopplerIdx': 124,
#   'peakVal': 4236.0,
#   'range': 120.3125,
#   'rangeIdx': 115,
#   'snr': 696.0},
#  {'angle': 5.281035900115967,
#   'doppler': 0.90625,
#   'dopplerIdx': 144,
#   'peakVal': 4644.0,
#   'range': 121.34375,
#   'rangeIdx': 116,
#   'snr': 1176.0},
#  {'angle': 5.997910022735596,
#   'doppler': 1.0625,
#   'dopplerIdx': 145,
#   'peakVal': 4206.0,
#   'range': 121.34375,
#   'rangeIdx': 116,
#   'snr': 732.0},
#  {'angle': 21.380691528320312,
#   'doppler': 28.265625,
#   'dopplerIdx': 311,
#   'peakVal': 4350.0,
#   'range': 9.78125,
#   'rangeIdx': 10,
#   'snr': 912.0},
#  {'angle': 4.894837379455566,
#   'doppler': -1.09375,
#   'dopplerIdx': 142,
#   'peakVal': 4218.0,
#   'range': 124.515625,
#   'rangeIdx': 119,
#   'snr': 654.0},
#  {'angle': 5.235382080078125,
#   'doppler': -0.984375,
#   'dopplerIdx': 143,
#   'peakVal': 4506.0,
#   'range': 124.515625,
#   'rangeIdx': 119,
#   'snr': 942.0},
#  {'angle': 21.504674911499023,
#   'doppler': 28.328125,
#   'dopplerIdx': 311,
#   'peakVal': 4200.0,
#   'range': 10.53125,
#   'rangeIdx': 9,
#   'snr': 792.0},
#  {'angle': 0.7833651304244995,
#   'doppler': -26.921875,
#   'dopplerIdx': 321,
#   'peakVal': 4554.0,
#   'range': 10.609375,
#   'rangeIdx': 10,
#   'snr': 1248.0},
#  {'angle': 0.8428211212158203,
#   'doppler': 29.140625,
#   'dopplerIdx': 325,
#   'peakVal': 4500.0,
#   'range': 10.671875,
#   'rangeIdx': 10,
#   'snr': 1194.0},
#  {'angle': 0.9127704501152039,
#   'doppler': 29.421875,
#   'dopplerIdx': 327,
#   'peakVal': 4338.0,
#   'range': 10.46875,
#   'rangeIdx': 10,
#   'snr': 1032.0},
#  {'angle': 3.681436538696289,
#   'doppler': -0.5625,
#   'dopplerIdx': 67,
#   'peakVal': 3804.0,
#   'range': 13.59375,
#   'rangeIdx': 13,
#   'snr': 612.0},
#  {'angle': -2.4941892623901367,
#   'doppler': -0.515625,
#   'dopplerIdx': 72,
#   'peakVal': 3834.0,
#   'range': 14.390625,
#   'rangeIdx': 14,
#   'snr': 684.0},
#  {'angle': -1.1576045751571655,
#   'doppler': -0.5,
#   'dopplerIdx': 94,
#   'peakVal': 3798.0,
#   'range': 18.5,
#   'rangeIdx': 18,
#   'snr': 618.0},
#  {'angle': -16.221887588500977,
#   'doppler': 41.21875,
#   'dopplerIdx': 265,
#   'peakVal': 3876.0,
#   'range': 74.484375,
#   'rangeIdx': 71,
#   'snr': 588.0},
#  {'angle': -1.7907847166061401,
#   'doppler': 26.71875,
#   'dopplerIdx': 135,
#   'peakVal': 4134.0,
#   'range': 75.21875,
#   'rangeIdx': 72,
#   'snr': 840.0},
#  {'angle': -0.43014201521873474,
#   'doppler': -28.015625,
#   'dopplerIdx': 203,
#   'peakVal': 3822.0,
#   'range': 86.4375,
#   'rangeIdx': 82,
#   'snr': 546.0},
#  {'angle': -4.140621662139893,
#   'doppler': -12.3125,
#   'dopplerIdx': 394,
#   'peakVal': 4038.0,
#   'range': 95.15625,
#   'rangeIdx': 91,
#   'snr': 630.0},
#  {'angle': 4.610598564147949,
#   'doppler': -42.34375,
#   'dopplerIdx': 184,
#   'peakVal': 4284.0,
#   'range': 107.546875,
#   'rangeIdx': 103,
#   'snr': 864.0},
#  {'angle': 4.2773756980896,
#   'doppler': -28.9375,
#   'dopplerIdx': 314,
#   'peakVal': 4650.0,
#   'range': 108.78125,
#   'rangeIdx': 104,
#   'snr': 1212.0},
#  {'angle': 5.403966903686523,
#   'doppler': -29.484375,
#   'dopplerIdx': 328,
#   'peakVal': 4380.0,
#   'range': 112.453125,
#   'rangeIdx': 108,
#   'snr': 942.0},
#  {'angle': 5.667475700378418,
#   'doppler': -28.890625,
#   'dopplerIdx': 335,
#   'peakVal': 4830.0,
#   'range': 112.640625,
#   'rangeIdx': 108,
#   'snr': 1398.0},
#  {'angle': 2.5431952476501465,
#   'doppler': 55.984375,
#   'dopplerIdx': 113,
#   'peakVal': 4272.0,
#   'range': 116.609375,
#   'rangeIdx': 111,
#   'snr': 702.0},
#  {'angle': 4.09854793548584,
#   'doppler': -29.578125,
#   'dopplerIdx': 375,
#   'peakVal': 4182.0,
#   'range': 121.359375,
#   'rangeIdx': 116,
#   'snr': 600.0},
#  {'angle': 6.004942893981934,
#   'doppler': -29.125,
#   'dopplerIdx': 395,
#   'peakVal': 4200.0,
#   'range': 124.3125,
#   'rangeIdx': 119,
#   'snr': 636.0},
#  {'angle': 4.596564769744873,
#   'doppler': 16.109375,
#   'dopplerIdx': 316,
#   'peakVal': 4338.0,
#   'range': 127.390625,
#   'rangeIdx': 122,
#   'snr': 780.0},
#  {'angle': 4.186203479766846,
#   'doppler': 28.96875,
#   'dopplerIdx': 445,
#   'peakVal': 4560.0,
#   'range': 129.453125,
#   'rangeIdx': 123,
#   'snr': 990.0},
#  {'angle': 4.042453765869141,
#   'doppler': 59.078125,
#   'dopplerIdx': 213,
#   'peakVal': 4044.0,
#   'range': 129.9375,
#   'rangeIdx': 124,
#   'snr': 540.0},
#  {'angle': 5.523409843444824,
#   'doppler': 16.46875,
#   'dopplerIdx': 337,
#   'peakVal': 4140.0,
#   'range': 130.8125,
#   'rangeIdx': 125,
#   'snr': 696.0},
#  {'angle': 5.663961410522461,
#   'doppler': 17.890625,
#   'dopplerIdx': 355,
#   'peakVal': 4212.0,
#   'range': 131.6875,
#   'rangeIdx': 126,
#   'snr': 798.0},
#  {'angle': 4.224775314331055,
#   'doppler': -13.0625,
#   'dopplerIdx': 79,
#   'peakVal': 4278.0,
#   'range': 133.34375,
#   'rangeIdx': 127,
#   'snr': 936.0},
#  {'angle': 4.494830131530762,
#   'doppler': 28.96875,
#   'dopplerIdx': 465,
#   'peakVal': 4470.0,
#   'range': 133.171875,
#   'rangeIdx': 127,
#   'snr': 1134.0},
#  {'angle': 5.72722053527832,
#   'doppler': 29.234375,
#   'dopplerIdx': 467,
#   'peakVal': 4428.0,
#   'range': 133.09375,
#   'rangeIdx': 127,
#   'snr': 1092.0},
#  {'angle': 5.723706245422363,
#   'doppler': 29.453125,
#   'dopplerIdx': 470,
#   'peakVal': 4068.0,
#   'range': 133.25,
#   'rangeIdx': 127,
#   'snr': 732.0},
#  {'angle': 7.667431354522705,
#   'doppler': 1.28125,
#   'dopplerIdx': 215,
#   'peakVal': 3846.0,
#   'range': 134.015625,
#   'rangeIdx': 128,
#   'snr': 522.0},
#  {'angle': -2.851278066635132,
#   'doppler': -29.59375,
#   'dopplerIdx': 501,
#   'peakVal': 3954.0,
#   'range': 145.109375,
#   'rangeIdx': 139,
#   'snr': 642.0},
#  {'angle': -2.7077298164367676,
#   'doppler': -29.265625,
#   'dopplerIdx': 504,
#   'peakVal': 4356.0,
#   'range': 144.96875,
#   'rangeIdx': 139,
#   'snr': 1050.0},
#  {'angle': -2.9423179626464844,
#   'doppler': -28.953125,
#   'dopplerIdx': 506,
#   'peakVal': 4218.0,
#   'range': 144.78125,
#   'rangeIdx': 139,
#   'snr': 912.0},
#  {'angle': -2.81976580619812,
#   'doppler': -28.875,
#   'dopplerIdx': 508,
#   'peakVal': 4206.0,
#   'range': 145.03125,
#   'rangeIdx': 139,
#   'snr': 900.0},
#  {'angle': -2.6132073402404785,
#   'doppler': -14.890625,
#   'dopplerIdx': 195,
#   'peakVal': 4044.0,
#   'range': 158.3125,
#   'rangeIdx': 151,
#   'snr': 564.0},
#  {'angle': -2.5852019786834717,
#   'doppler': 15.953125,
#   'dopplerIdx': 510,
#   'peakVal': 4068.0,
#   'range': 164.03125,
#   'rangeIdx': 157,
#   'snr': 648.0},
#  {'angle': 5.892431259155273,
#   'doppler': -69.203125,
#   'dopplerIdx': 271,
#   'peakVal': 4056.0,
#   'range': 170.28125,
#   'rangeIdx': 163,
#   'snr': 564.0},
#  {'angle': 5.93110466003418,
#   'doppler': -68.546875,
#   'dopplerIdx': 279,
#   'peakVal': 4308.0,
#   'range': 170.578125,
#   'rangeIdx': 163,
#   'snr': 816.0},
#  {'angle': 5.653419017791748,
#   'doppler': -42.09375,
#   'dopplerIdx': 15,
#   'peakVal': 4272.0,
#   'range': 171.4375,
#   'rangeIdx': 164,
#   'snr': 756.0},
#  {'angle': 3.6148576736450195,
#   'doppler': -42.84375,
#   'dopplerIdx': 13,
#   'peakVal': 4224.0,
#   'range': 172.421875,
#   'rangeIdx': 165,
#   'snr': 732.0},
#  {'angle': 6.075274467468262,
#   'doppler': -29.359375,
#   'dopplerIdx': 137,
#   'peakVal': 4290.0,
#   'range': 172.34375,
#   'rangeIdx': 165,
#   'snr': 792.0},
#  {'angle': 6.1420979499816895,
#   'doppler': -29.265625,
#   'dopplerIdx': 140,
#   'peakVal': 4878.0,
#   'range': 172.703125,
#   'rangeIdx': 165,
#   'snr': 1380.0},
#  {'angle': 4.315951824188232,
#   'doppler': -14.890625,
#   'dopplerIdx': 273,
#   'peakVal': 4284.0,
#   'range': 172.90625,
#   'rangeIdx': 165,
#   'snr': 792.0},
#  {'angle': 4.68427848815918,
#   'doppler': -30.234375,
#   'dopplerIdx': 133,
#   'peakVal': 4026.0,
#   'range': 173.140625,
#   'rangeIdx': 166,
#   'snr': 516.0},
#  {'angle': 6.180788993835449,
#   'doppler': -29.84375,
#   'dopplerIdx': 135,
#   'peakVal': 4218.0,
#   'range': 172.890625,
#   'rangeIdx': 166,
#   'snr': 702.0},
#  {'angle': 4.950997352600098,
#   'doppler': -29.046875,
#   'dopplerIdx': 143,
#   'peakVal': 4974.0,
#   'range': 172.859375,
#   'rangeIdx': 166,
#   'snr': 1458.0},
#  {'angle': 4.72287654876709,
#   'doppler': -28.53125,
#   'dopplerIdx': 148,
#   'peakVal': 4164.0,
#   'range': 172.96875,
#   'rangeIdx': 166,
#   'snr': 654.0},
#  {'angle': 6.089341640472412,
#   'doppler': -16.203125,
#   'dopplerIdx': 272,
#   'peakVal': 4392.0,
#   'range': 174.96875,
#   'rangeIdx': 167,
#   'snr': 798.0},
#  {'angle': 5.917041301727295,
#   'doppler': -43.796875,
#   'dopplerIdx': 23,
#   'peakVal': 4230.0,
#   'range': 175.875,
#   'rangeIdx': 168,
#   'snr': 636.0},
#  {'angle': 6.30743408203125,
#   'doppler': -58.96875,
#   'dopplerIdx': 394,
#   'peakVal': 4266.0,
#   'range': 175.734375,
#   'rangeIdx': 168,
#   'snr': 666.0},
#  {'angle': 5.794002056121826,
#   'doppler': 25.578125,
#   'dopplerIdx': 154,
#   'peakVal': 4344.0,
#   'range': 176.703125,
#   'rangeIdx': 169,
#   'snr': 672.0},
#  {'angle': 6.1420979499816895,
#   'doppler': -26.796875,
#   'dopplerIdx': 191,
#   'peakVal': 4374.0,
#   'range': 178.078125,
#   'rangeIdx': 170,
#   'snr': 744.0},
#  {'angle': 6.286324501037598,
#   'doppler': 43.171875,
#   'dopplerIdx': 321,
#   'peakVal': 4242.0,
#   'range': 177.640625,
#   'rangeIdx': 170,
#   'snr': 612.0},
#  {'angle': 6.004942893981934,
#   'doppler': -41.640625,
#   'dopplerIdx': 65,
#   'peakVal': 4242.0,
#   'range': 179.96875,
#   'rangeIdx': 172,
#   'snr': 600.0},
#  {'angle': 5.3126444816589355,
#   'doppler': -39.078125,
#   'dopplerIdx': 86,
#   'peakVal': 4308.0,
#   'range': 179.609375,
#   'rangeIdx': 172,
#   'snr': 666.0},
#  {'angle': 5.5409770011901855,
#   'doppler': -39.0,
#   'dopplerIdx': 88,
#   'peakVal': 4224.0,
#   'range': 179.734375,
#   'rangeIdx': 172,
#   'snr': 582.0},
#  {'angle': 6.89534330368042,
#   'doppler': 1.71875,
#   'dopplerIdx': 464,
#   'peakVal': 4296.0,
#   'range': 180.03125,
#   'rangeIdx': 172,
#   'snr': 660.0},
#  {'angle': 5.049289226531982,
#   'doppler': -12.78125,
#   'dopplerIdx': 337,
#   'peakVal': 4656.0,
#   'range': 181.25,
#   'rangeIdx': 173,
#   'snr': 1074.0},
#  {'angle': 6.4094767570495605,
#   'doppler': 27.5,
#   'dopplerIdx': 204,
#   'peakVal': 4320.0,
#   'range': 182.78125,
#   'rangeIdx': 174,
#   'snr': 792.0},
#  {'angle': 5.790487289428711,
#   'doppler': -27.453125,
#   'dopplerIdx': 210,
#   'peakVal': 4662.0,
#   'range': 182.796875,
#   'rangeIdx': 174,
#   'snr': 1134.0},
#  {'angle': 6.814332008361816,
#   'doppler': -69.03125,
#   'dopplerIdx': 335,
#   'peakVal': 4578.0,
#   'range': 181.890625,
#   'rangeIdx': 174,
#   'snr': 1050.0},
#  {'angle': 6.1420979499816895,
#   'doppler': -11.53125,
#   'dopplerIdx': 352,
#   'peakVal': 4284.0,
#   'range': 181.9375,
#   'rangeIdx': 174,
#   'snr': 762.0},
#  {'angle': 6.286324501037598,
#   'doppler': 11.515625,
#   'dopplerIdx': 63,
#   'peakVal': 4152.0,
#   'range': 183.984375,
#   'rangeIdx': 176,
#   'snr': 594.0},
#  {'angle': 6.332063674926758,
#   'doppler': -43.640625,
#   'dopplerIdx': 67,
#   'peakVal': 4362.0,
#   'range': 183.84375,
#   'rangeIdx': 176,
#   'snr': 804.0},
#  {'angle': 5.973296642303467,
#   'doppler': -43.046875,
#   'dopplerIdx': 73,
#   'peakVal': 4314.0,
#   'range': 184.03125,
#   'rangeIdx': 176,
#   'snr': 762.0},
#  {'angle': 6.451706886291504,
#   'doppler': 13.65625,
#   'dopplerIdx': 83,
#   'peakVal': 4386.0,
#   'range': 184.015625,
#   'rangeIdx': 176,
#   'snr': 828.0},
#  {'angle': 6.314471244812012,
#   'doppler': 14.0,
#   'dopplerIdx': 86,
#   'peakVal': 4368.0,
#   'range': 184.015625,
#   'rangeIdx': 176,
#   'snr': 816.0},
#  {'angle': 5.77291202545166,
#   'doppler': -27.953125,
#   'dopplerIdx': 210,
#   'peakVal': 4764.0,
#   'range': 183.640625,
#   'rangeIdx': 176,
#   'snr': 1212.0},
#  {'angle': 6.047141075134277,
#   'doppler': 26.09375,
#   'dopplerIdx': 203,
#   'peakVal': 4728.0,
#   'range': 185.03125,
#   'rangeIdx': 177,
#   'snr': 1020.0},
#  {'angle': 5.948684215545654,
#   'doppler': 27.3125,
#   'dopplerIdx': 215,
#   'peakVal': 4596.0,
#   'range': 185.09375,
#   'rangeIdx': 177,
#   'snr': 894.0},
#  {'angle': 6.3039164543151855,
#   'doppler': 27.609375,
#   'dopplerIdx': 221,
#   'peakVal': 4374.0,
#   'range': 185.734375,
#   'rangeIdx': 177,
#   'snr': 672.0},
#  {'angle': 6.423552989959717,
#   'doppler': -17.375,
#   'dopplerIdx': 322,
#   'peakVal': 4464.0,
#   'range': 186.4375,
#   'rangeIdx': 178,
#   'snr': 654.0},
#  {'angle': 6.008459568023682,
#   'doppler': -16.5625,
#   'dopplerIdx': 328,
#   'peakVal': 4746.0,
#   'range': 186.1875,
#   'rangeIdx': 178,
#   'snr': 936.0},
#  {'angle': 6.071757793426514,
#   'doppler': -16.125,
#   'dopplerIdx': 335,
#   'peakVal': 4656.0,
#   'range': 186.703125,
#   'rangeIdx': 178,
#   'snr': 840.0},
#  {'angle': 5.881884574890137,
#   'doppler': -14.78125,
#   'dopplerIdx': 346,
#   'peakVal': 4512.0,
#   'range': 186.453125,
#   'rangeIdx': 178,
#   'snr': 702.0},
#  {'angle': 6.082308292388916,
#   'doppler': 29.578125,
#   'dopplerIdx': 261,
#   'peakVal': 4542.0,
#   'range': 189.796875,
#   'rangeIdx': 181,
#   'snr': 876.0},
#  {'angle': 6.377806186676025,
#   'doppler': 30.03125,
#   'dopplerIdx': 264,
#   'peakVal': 4380.0,
#   'range': 189.65625,
#   'rangeIdx': 181,
#   'snr': 714.0},
#  {'angle': 5.744793891906738,
#   'doppler': 31.5,
#   'dopplerIdx': 277,
#   'peakVal': 4404.0,
#   'range': 189.609375,
#   'rangeIdx': 181,
#   'snr': 738.0},
#  {'angle': 6.205411911010742,
#   'doppler': -23.921875,
#   'dopplerIdx': 280,
#   'peakVal': 4416.0,
#   'range': 189.71875,
#   'rangeIdx': 181,
#   'snr': 750.0},
#  {'angle': 6.508019924163818,
#   'doppler': 56.890625,
#   'dopplerIdx': 8,
#   'peakVal': 4302.0,
#   'range': 191.40625,
#   'rangeIdx': 183,
#   'snr': 732.0},
#  {'angle': 6.479862689971924,
#   'doppler': 57.21875,
#   'dopplerIdx': 12,
#   'peakVal': 4512.0,
#   'range': 191.53125,
#   'rangeIdx': 183,
#   'snr': 948.0},
#  {'angle': 6.360212326049805,
#   'doppler': 58.265625,
#   'dopplerIdx': 21,
#   'peakVal': 4488.0,
#   'range': 191.296875,
#   'rangeIdx': 183,
#   'snr': 918.0},
#  {'angle': 6.483382701873779,
#   'doppler': 17.90625,
#   'dopplerIdx': 163,
#   'peakVal': 4290.0,
#   'range': 191.65625,
#   'rangeIdx': 183,
#   'snr': 720.0},
#  {'angle': 4.9615278244018555,
#   'doppler': 58.546875,
#   'dopplerIdx': 27,
#   'peakVal': 4260.0,
#   'range': 192.0625,
#   'rangeIdx': 184,
#   'snr': 768.0},
#  {'angle': 6.050657272338867,
#   'doppler': 15.28125,
#   'dopplerIdx': 141,
#   'peakVal': 4134.0,
#   'range': 192.09375,
#   'rangeIdx': 184,
#   'snr': 648.0},
#  {'angle': 5.491790294647217,
#   'doppler': 15.875,
#   'dopplerIdx': 145,
#   'peakVal': 4752.0,
#   'range': 191.84375,
#   'rangeIdx': 184,
#   'snr': 1260.0},
#  {'angle': 6.374287128448486,
#   'doppler': 15.9375,
#   'dopplerIdx': 148,
#   'peakVal': 4566.0,
#   'range': 192.21875,
#   'rangeIdx': 184,
#   'snr': 1074.0},
#  {'angle': 5.667475700378418,
#   'doppler': 28.4375,
#   'dopplerIdx': 272,
#   'peakVal': 4452.0,
#   'range': 193.9375,
#   'rangeIdx': 185,
#   'snr': 996.0},
#  {'angle': 5.794002056121826,
#   'doppler': 28.90625,
#   'dopplerIdx': 276,
#   'peakVal': 4500.0,
#   'range': 193.890625,
#   'rangeIdx': 185,
#   'snr': 1044.0},
#  {'angle': 6.1139607429504395,
#   'doppler': 29.1875,
#   'dopplerIdx': 279,
#   'peakVal': 4176.0,
#   'range': 193.890625,
#   'rangeIdx': 185,
#   'snr': 714.0},
#  {'angle': 6.4376301765441895,
#   'doppler': 41.46875,
#   'dopplerIdx': 395,
#   'peakVal': 4236.0,
#   'range': 194.484375,
#   'rangeIdx': 186,
#   'snr': 744.0},
#  {'angle': 5.846729755401611,
#   'doppler': 56.1875,
#   'dopplerIdx': 24,
#   'peakVal': 4038.0,
#   'range': 195.5625,
#   'rangeIdx': 187,
#   'snr': 582.0},
#  {'angle': 5.410992622375488,
#   'doppler': 44.734375,
#   'dopplerIdx': 465,
#   'peakVal': 3942.0,
#   'range': 202.0,
#   'rangeIdx': 193,
#   'snr': 564.0},
#  {'angle': -0.01398822758346796,
#   'doppler': -58.078125,
#   'dopplerIdx': 71,
#   'peakVal': 4056.0,
#   'range': 209.546875,
#   'rangeIdx': 200,
#   'snr': 708.0},
#  {'angle': 0.3881762623786926,
#   'doppler': -59.140625,
#   'dopplerIdx': 65,
#   'peakVal': 3948.0,
#   'range': 210.28125,
#   'rangeIdx': 201,
#   'snr': 576.0},
#  {'angle': -0.9372530579566956,
#   'doppler': -44.0,
#   'dopplerIdx': 202,
#   'peakVal': 3936.0,
#   'range': 209.796875,
#   'rangeIdx': 201,
#   'snr': 570.0},
#  {'angle': 0.44063350558280945,
#   'doppler': -12.484375,
#   'dopplerIdx': 18,
#   'peakVal': 4290.0,
#   'range': 216.859375,
#   'rangeIdx': 207,
#   'snr': 744.0},
#  {'angle': -0.8987804055213928,
#   'doppler': -28.25,
#   'dopplerIdx': 382,
#   'peakVal': 4056.0,
#   'range': 216.421875,
#   'rangeIdx': 207,
#   'snr': 516.0},
#  {'angle': 0.12939120829105377,
#   'doppler': -28.328125,
#   'dopplerIdx': 394,
#   'peakVal': 4668.0,
#   'range': 218.75,
#   'rangeIdx': 209,
#   'snr': 1218.0},
#  {'angle': 0.5980075597763062,
#   'doppler': -29.640625,
#   'dopplerIdx': 385,
#   'peakVal': 4302.0,
#   'range': 219.34375,
#   'rangeIdx': 210,
#   'snr': 882.0},
#  {'angle': 0.4895939230918884,
#   'doppler': -29.421875,
#   'dopplerIdx': 387,
#   'peakVal': 4656.0,
#   'range': 219.390625,
#   'rangeIdx': 210,
#   'snr': 1236.0},
#  {'angle': 0.43363919854164124,
#   'doppler': -29.140625,
#   'dopplerIdx': 390,
#   'peakVal': 4884.0,
#   'range': 219.5,
#   'rangeIdx': 210,
#   'snr': 1464.0},
#  {'angle': 0.45112496614456177,
#   'doppler': -28.0,
#   'dopplerIdx': 399,
#   'peakVal': 4098.0,
#   'range': 219.15625,
#   'rangeIdx': 210,
#   'snr': 678.0},
#  {'angle': -0.8603083491325378,
#   'doppler': 39.78125,
#   'dopplerIdx': 10,
#   'peakVal': 4764.0,
#   'range': 221.140625,
#   'rangeIdx': 211,
#   'snr': 1314.0},
#  {'angle': -0.5595380067825317,
#   'doppler': 40.265625,
#   'dopplerIdx': 15,
#   'peakVal': 3984.0,
#   'range': 221.234375,
#   'rangeIdx': 211,
#   'snr': 534.0},
#  {'angle': -0.5910130739212036,
#   'doppler': -28.71875,
#   'dopplerIdx': 396,
#   'peakVal': 4428.0,
#   'range': 219.859375,
#   'rangeIdx': 211,
#   'snr': 978.0},
#  {'angle': 0.5875158309936523,
#   'doppler': 37.796875,
#   'dopplerIdx': 503,
#   'peakVal': 4098.0,
#   'range': 221.078125,
#   'rangeIdx': 211,
#   'snr': 648.0},
#  {'angle': -0.47910240292549133,
#   'doppler': -57.921875,
#   'dopplerIdx': 145,
#   'peakVal': 4242.0,
#   'range': 223.15625,
#   'rangeIdx': 213,
#   'snr': 690.0},
#  {'angle': -1.60885751247406,
#   'doppler': 1.171875,
#   'dopplerIdx': 193,
#   'peakVal': 4272.0,
#   'range': 226.0625,
#   'rangeIdx': 216,
#   'snr': 606.0},
#  {'angle': 0.39517053961753845,
#   'doppler': -40.703125,
#   'dopplerIdx': 322,
#   'peakVal': 4446.0,
#   'range': 226.59375,
#   'rangeIdx': 217,
#   'snr': 780.0},
#  {'angle': 0.60849928855896,
#   'doppler': -39.3125,
#   'dopplerIdx': 336,
#   'peakVal': 4260.0,
#   'range': 226.890625,
#   'rangeIdx': 217,
#   'snr': 600.0},
#  {'angle': 0.11190588772296906,
#   'doppler': -39.265625,
#   'dopplerIdx': 338,
#   'peakVal': 4350.0,
#   'range': 227.109375,
#   'rangeIdx': 217,
#   'snr': 690.0},
#  {'angle': -0.010491170920431614,
#   'doppler': -27.109375,
#   'dopplerIdx': 452,
#   'peakVal': 4308.0,
#   'range': 227.484375,
#   'rangeIdx': 217,
#   'snr': 648.0},
#  {'angle': 0.4930911064147949,
#   'doppler': -12.96875,
#   'dopplerIdx': 74,
#   'peakVal': 4356.0,
#   'range': 228.203125,
#   'rangeIdx': 218,
#   'snr': 750.0},
#  {'angle': -0.8952829241752625,
#   'doppler': -12.5,
#   'dopplerIdx': 78,
#   'peakVal': 4404.0,
#   'range': 228.21875,
#   'rangeIdx': 218,
#   'snr': 798.0},
#  {'angle': -0.06294703483581543,
#   'doppler': 2.640625,
#   'dopplerIdx': 216,
#   'peakVal': 4314.0,
#   'range': 227.90625,
#   'rangeIdx': 218,
#   'snr': 708.0},
#  {'angle': 0.5105770826339722,
#   'doppler': 41.78125,
#   'dopplerIdx': 70,
#   'peakVal': 4266.0,
#   'range': 229.015625,
#   'rangeIdx': 219,
#   'snr': 732.0},
#  {'angle': 0.6539638042449951,
#   'doppler': -68.484375,
#   'dopplerIdx': 80,
#   'peakVal': 4362.0,
#   'range': 229.25,
#   'rangeIdx': 219,
#   'snr': 828.0},
#  {'angle': 0.5805213451385498,
#   'doppler': -67.75,
#   'dopplerIdx': 88,
#   'peakVal': 4476.0,
#   'range': 229.453125,
#   'rangeIdx': 219,
#   'snr': 942.0},
#  {'angle': 0.6609584093093872,
#   'doppler': -67.53125,
#   'dopplerIdx': 90,
#   'peakVal': 4446.0,
#   'range': 229.328125,
#   'rangeIdx': 219,
#   'snr': 912.0},
#  {'angle': 0.03846762701869011,
#   'doppler': 0.40625,
#   'dopplerIdx': 202,
#   'peakVal': 5466.0,
#   'range': 229.21875,
#   'rangeIdx': 219,
#   'snr': 1932.0},
#  {'angle': -0.5140742659568787,
#   'doppler': -29.75,
#   'dopplerIdx': 441,
#   'peakVal': 4140.0,
#   'range': 230.0,
#   'rangeIdx': 220,
#   'snr': 588.0},
#  {'angle': -1.0246922969818115,
#   'doppler': -29.421875,
#   'dopplerIdx': 444,
#   'peakVal': 4170.0,
#   'range': 230.03125,
#   'rangeIdx': 220,
#   'snr': 618.0},
#  {'angle': 0.3462107479572296,
#   'doppler': 11.640625,
#   'dopplerIdx': 315,
#   'peakVal': 4308.0,
#   'range': 230.890625,
#   'rangeIdx': 221,
#   'snr': 672.0},
#  {'angle': 0.5665324330329895,
#   'doppler': 11.890625,
#   'dopplerIdx': 317,
#   'peakVal': 4368.0,
#   'range': 230.90625,
#   'rangeIdx': 221,
#   'snr': 732.0},
#  {'angle': -0.1398824006319046,
#   'doppler': 13.265625,
#   'dopplerIdx': 331,
#   'peakVal': 4824.0,
#   'range': 231.09375,
#   'rangeIdx': 221,
#   'snr': 1194.0},
#  {'angle': -0.7868625521659851,
#   'doppler': 26.765625,
#   'dopplerIdx': 454,
#   'peakVal': 4632.0,
#   'range': 230.890625,
#   'rangeIdx': 221,
#   'snr': 1002.0},
#  {'angle': -0.7658782601356506,
#   'doppler': -27.734375,
#   'dopplerIdx': 462,
#   'peakVal': 4470.0,
#   'range': 230.5,
#   'rangeIdx': 221,
#   'snr': 834.0},
#  {'angle': 0.4965883195400238,
#   'doppler': -15.359375,
#   'dopplerIdx': 81,
#   'peakVal': 4452.0,
#   'range': 233.671875,
#   'rangeIdx': 223,
#   'snr': 720.0},
#  {'angle': -0.734402060508728,
#   'doppler': 1.796875,
#   'dopplerIdx': 259,
#   'peakVal': 4548.0,
#   'range': 237.515625,
#   'rangeIdx': 227,
#   'snr': 840.0},
#  {'angle': -0.5770241618156433,
#   'doppler': 57.90625,
#   'dopplerIdx': 264,
#   'peakVal': 4386.0,
#   'range': 237.609375,
#   'rangeIdx': 227,
#   'snr': 684.0},
#  {'angle': -0.4895939230918884,
#   'doppler': 58.65625,
#   'dopplerIdx': 272,
#   'peakVal': 4506.0,
#   'range': 237.765625,
#   'rangeIdx': 227,
#   'snr': 798.0},
#  {'angle': -1.143613576889038,
#   'doppler': 15.65625,
#   'dopplerIdx': 391,
#   'peakVal': 4446.0,
#   'range': 238.265625,
#   'rangeIdx': 228,
#   'snr': 642.0},
#  {'angle': 0.563035249710083,
#   'doppler': 17.9375,
#   'dopplerIdx': 414,
#   'peakVal': 4536.0,
#   'range': 238.6875,
#   'rangeIdx': 228,
#   'snr': 732.0},
#  {'angle': -0.14337947964668274,
#   'doppler': 29.296875,
#   'dopplerIdx': 13,
#   'peakVal': 4908.0,
#   'range': 239.8125,
#   'rangeIdx': 229,
#   'snr': 1386.0},
#  {'angle': 0.6714502573013306,
#   'doppler': 16.25,
#   'dopplerIdx': 402,
#   'peakVal': 4398.0,
#   'range': 239.265625,
#   'rangeIdx': 229,
#   'snr': 882.0},
#  {'angle': -0.23430344462394714,
#   'doppler': 42.6875,
#   'dopplerIdx': 141,
#   'peakVal': 4626.0,
#   'range': 240.828125,
#   'rangeIdx': 230,
#   'snr': 1080.0},
#  {'angle': -0.2203151285648346,
#   'doppler': 54.984375,
#   'dopplerIdx': 259,
#   'peakVal': 4146.0,
#   'range': 241.71875,
#   'rangeIdx': 231,
#   'snr': 618.0},
#  {'angle': -0.4056619703769684,
#   'doppler': 55.390625,
#   'dopplerIdx': 263,
#   'peakVal': 4578.0,
#   'range': 241.71875,
#   'rangeIdx': 231,
#   'snr': 1050.0},
#  {'angle': -0.5000854730606079,
#   'doppler': 55.984375,
#   'dopplerIdx': 269,
#   'peakVal': 4230.0,
#   'range': 241.84375,
#   'rangeIdx': 231,
#   'snr': 708.0},
#  {'angle': 0.44063350558280945,
#   'doppler': 56.40625,
#   'dopplerIdx': 273,
#   'peakVal': 4092.0,
#   'range': 241.84375,
#   'rangeIdx': 231,
#   'snr': 570.0},
#  {'angle': -1.2590417861938477,
#   'doppler': 15.46875,
#   'dopplerIdx': 405,
#   'peakVal': 4098.0,
#   'range': 241.1875,
#   'rangeIdx': 231,
#   'snr': 576.0},
#  {'angle': -1.0176969766616821,
#   'doppler': 68.625,
#   'dopplerIdx': 388,
#   'peakVal': 3978.0,
#   'range': 242.296875,
#   'rangeIdx': 232,
#   'snr': 516.0},
#  {'angle': -1.2205651998519897,
#   'doppler': 68.84375,
#   'dopplerIdx': 390,
#   'peakVal': 3990.0,
#   'range': 242.328125,
#   'rangeIdx': 232,
#   'snr': 528.0},
#  {'angle': 0.6469692587852478,
#   'doppler': 44.78125,
#   'dopplerIdx': 205,
#   'peakVal': 3912.0,
#   'range': 249.078125,
#   'rangeIdx': 238,
#   'snr': 642.0},
#  {'angle': 5.741279602050781,
#   'doppler': -29.09375,
#   'dopplerIdx': 142,
#   'peakVal': 4470.0,
#   'range': 172.234375,
#   'rangeIdx': 165,
#   'snr': 972.0},
#  {'angle': 5.410992622375488,
#   'doppler': 15.515625,
#   'dopplerIdx': 144,
#   'peakVal': 4416.0,
#   'range': 191.9375,
#   'rangeIdx': 183,
#   'snr': 852.0},
#  {'angle': 5.562058448791504,
#   'doppler': 15.84375,
#   'dopplerIdx': 145,
#   'peakVal': 4626.0,
#   'range': 191.921875,
#   'rangeIdx': 183,
#   'snr': 1062.0},
#  {'angle': 5.59016752243042,
#   'doppler': 15.828125,
#   'dopplerIdx': 146,
#   'peakVal': 4410.0,
#   'range': 192.5625,
#   'rangeIdx': 183,
#   'snr': 846.0},
#  {'angle': 5.179197788238525,
#   'doppler': -28.984375,
#   'dopplerIdx': 143,
#   'peakVal': 4866.0,
#   'range': 172.875,
#   'rangeIdx': 165,
#   'snr': 1374.0},
#  {'angle': 5.941651821136475,
#   'doppler': -28.96875,
#   'dopplerIdx': 144,
#   'peakVal': 4644.0,
#   'range': 172.453125,
#   'rangeIdx': 165,
#   'snr': 1152.0},
#  {'angle': 5.68856143951416,
#   'doppler': -29.265625,
#   'dopplerIdx': 332,
#   'peakVal': 4572.0,
#   'range': 112.46875,
#   'rangeIdx': 108,
#   'snr': 1140.0},
#  {'angle': 5.663961410522461,
#   'doppler': -29.0,
#   'dopplerIdx': 333,
#   'peakVal': 4740.0,
#   'range': 112.75,
#   'rangeIdx': 108,
#   'snr': 1302.0},
#  {'angle': 5.1195068359375,
#   'doppler': 15.625,
#   'dopplerIdx': 143,
#   'peakVal': 4278.0,
#   'range': 191.734375,
#   'rangeIdx': 184,
#   'snr': 786.0},
#  {'angle': 5.372354030609131,
#   'doppler': 15.734375,
#   'dopplerIdx': 144,
#   'peakVal': 4518.0,
#   'range': 191.84375,
#   'rangeIdx': 184,
#   'snr': 1032.0},
#  {'angle': 4.372065544128418,
#   'doppler': -29.140625,
#   'dopplerIdx': 334,
#   'peakVal': 4770.0,
#   'range': 112.578125,
#   'rangeIdx': 108,
#   'snr': 1332.0},
#  {'angle': 5.548003673553467,
#   'doppler': 15.875,
#   'dopplerIdx': 146,
#   'peakVal': 4710.0,
#   'range': 191.984375,
#   'rangeIdx': 184,
#   'snr': 1224.0},
#  {'angle': 5.790487289428711,
#   'doppler': -29.265625,
#   'dopplerIdx': 139,
#   'peakVal': 4728.0,
#   'range': 172.828125,
#   'rangeIdx': 166,
#   'snr': 1218.0},
#  {'angle': 6.14913272857666,
#   'doppler': -29.25,
#   'dopplerIdx': 140,
#   'peakVal': 4800.0,
#   'range': 172.6875,
#   'rangeIdx': 166,
#   'snr': 1290.0},
#  {'angle': 6.427072048187256,
#   'doppler': -29.171875,
#   'dopplerIdx': 141,
#   'peakVal': 4734.0,
#   'range': 173.15625,
#   'rangeIdx': 166,
#   'snr': 1224.0},
#  {'angle': 5.864306926727295,
#   'doppler': 28.828125,
#   'dopplerIdx': 277,
#   'peakVal': 4314.0,
#   'range': 193.84375,
#   'rangeIdx': 185,
#   'snr': 852.0},
#  {'angle': 5.365329265594482,
#   'doppler': -29.046875,
#   'dopplerIdx': 142,
#   'peakVal': 4968.0,
#   'range': 173.078125,
#   'rangeIdx': 166,
#   'snr': 1458.0},
#  {'angle': 12.216653823852539,
#   'doppler': -26.703125,
#   'dopplerIdx': 323,
#   'peakVal': 4194.0,
#   'range': 10.21875,
#   'rangeIdx': 9,
#   'snr': 966.0},
#  {'angle': 5.871337890625,
#   'doppler': -28.875,
#   'dopplerIdx': 336,
#   'peakVal': 4686.0,
#   'range': 112.90625,
#   'rangeIdx': 108,
#   'snr': 1248.0},
#  {'angle': 7.653316497802734,
#   'doppler': -28.46875,
#   'dopplerIdx': 337,
#   'peakVal': 4254.0,
#   'range': 112.734375,
#   'rangeIdx': 108,
#   'snr': 816.0},
#  {'angle': 5.569085121154785,
#   'doppler': -29.078125,
#   'dopplerIdx': 333,
#   'peakVal': 4452.0,
#   'range': 112.609375,
#   'rangeIdx': 109,
#   'snr': 1026.0},
#  {'angle': 4.35452938079834,
#   'doppler': -28.875,
#   'dopplerIdx': 335,
#   'peakVal': 4206.0,
#   'range': 113.65625,
#   'rangeIdx': 109,
#   'snr': 780.0},
#  {'angle': 5.846729755401611,
#   'doppler': -28.78125,
#   'dopplerIdx': 336,
#   'peakVal': 4434.0,
#   'range': 112.71875,
#   'rangeIdx': 109,
#   'snr': 1008.0},
#  {'angle': 0.8393236994743347,
#   'doppler': 29.125,
#   'dopplerIdx': 325,
#   'peakVal': 4038.0,
#   'range': 11.453125,
#   'rangeIdx': 9,
#   'snr': 810.0},
#  {'angle': 0.8008521199226379,
#   'doppler': 29.390625,
#   'dopplerIdx': 326,
#   'peakVal': 4230.0,
#   'range': 10.3125,
#   'rangeIdx': 9,
#   'snr': 1002.0},
#  {'angle': 0.6749476194381714,
#   'doppler': -29.421875,
#   'dopplerIdx': 387,
#   'peakVal': 4368.0,
#   'range': 219.9375,
#   'rangeIdx': 209,
#   'snr': 924.0},
#  {'angle': 0.6504665613174438,
#   'doppler': -29.359375,
#   'dopplerIdx': 388,
#   'peakVal': 4254.0,
#   'range': 219.78125,
#   'rangeIdx': 209,
#   'snr': 810.0},
#  {'angle': 0.45462214946746826,
#   'doppler': -29.4375,
#   'dopplerIdx': 389,
#   'peakVal': 4344.0,
#   'range': 218.28125,
#   'rangeIdx': 209,
#   'snr': 900.0},
#  {'angle': 0.3287251591682434,
#   'doppler': -29.109375,
#   'dopplerIdx': 390,
#   'peakVal': 4500.0,
#   'range': 219.59375,
#   'rangeIdx': 209,
#   'snr': 1050.0},
#  {'angle': 0.05944997817277908,
#   'doppler': -29.21875,
#   'dopplerIdx': 391,
#   'peakVal': 4542.0,
#   'range': 219.5,
#   'rangeIdx': 209,
#   'snr': 1098.0},
#  {'angle': -0.0839293971657753,
#   'doppler': -28.53125,
#   'dopplerIdx': 392,
#   'peakVal': 4644.0,
#   'range': 218.25,
#   'rangeIdx': 209,
#   'snr': 1200.0},
#  {'angle': 0.020982341840863228,
#   'doppler': -28.421875,
#   'dopplerIdx': 393,
#   'peakVal': 4554.0,
#   'range': 218.390625,
#   'rangeIdx': 209,
#   'snr': 1104.0},
#  {'angle': 4.3966169357299805,
#   'doppler': 0.40625,
#   'dopplerIdx': 122,
#   'peakVal': 4584.0,
#   'range': 118.4375,
#   'rangeIdx': 115,
#   'snr': 978.0},
#  {'angle': 0.01398822758346796,
#   'doppler': -28.328125,
#   'dopplerIdx': 395,
#   'peakVal': 4524.0,
#   'range': 218.484375,
#   'rangeIdx': 209,
#   'snr': 1080.0},
#  {'angle': -0.7134180068969727,
#   'doppler': 39.640625,
#   'dopplerIdx': 8,
#   'peakVal': 4368.0,
#   'range': 220.625,
#   'rangeIdx': 210,
#   'snr': 948.0},
#  {'angle': 0.5140742659568787,
#   'doppler': -29.640625,
#   'dopplerIdx': 384,
#   'peakVal': 4200.0,
#   'range': 219.265625,
#   'rangeIdx': 210,
#   'snr': 774.0},
#  {'angle': 15.825299263000488,
#   'doppler': 0.390625,
#   'dopplerIdx': 393,
#   'peakVal': 4128.0,
#   'range': 73.265625,
#   'rangeIdx': 70,
#   'snr': 822.0},
#  {'angle': 0.5805213451385498,
#   'doppler': -29.578125,
#   'dopplerIdx': 386,
#   'peakVal': 4206.0,
#   'range': 219.390625,
#   'rangeIdx': 210,
#   'snr': 780.0},
#  {'angle': 0.81134432554245,
#   'doppler': 29.390625,
#   'dopplerIdx': 327,
#   'peakVal': 4182.0,
#   'range': 10.546875,
#   'rangeIdx': 9,
#   'snr': 954.0},
#  {'angle': 0.5385547280311584,
#   'doppler': -29.375,
#   'dopplerIdx': 388,
#   'peakVal': 4584.0,
#   'range': 219.53125,
#   'rangeIdx': 210,
#   'snr': 1158.0},
#  {'angle': 0.45462214946746826,
#   'doppler': -29.296875,
#   'dopplerIdx': 389,
#   'peakVal': 4734.0,
#   'range': 219.546875,
#   'rangeIdx': 210,
#   'snr': 1314.0},
#  {'angle': 5.709648132324219,
#   'doppler': -0.90625,
#   'dopplerIdx': 143,
#   'peakVal': 4638.0,
#   'range': 124.515625,
#   'rangeIdx': 119,
#   'snr': 1080.0},
#  {'angle': 0.18884141743183136,
#   'doppler': -29.140625,
#   'dopplerIdx': 391,
#   'peakVal': 4884.0,
#   'range': 219.09375,
#   'rangeIdx': 210,
#   'snr': 1464.0},
#  {'angle': 0.07693526893854141,
#   'doppler': -28.328125,
#   'dopplerIdx': 394,
#   'peakVal': 4626.0,
#   'range': 218.75,
#   'rangeIdx': 210,
#   'snr': 1206.0},
#  {'angle': 0.010491170920431614,
#   'doppler': -28.203125,
#   'dopplerIdx': 395,
#   'peakVal': 4308.0,
#   'range': 218.359375,
#   'rangeIdx': 210,
#   'snr': 888.0},
#  {'angle': -0.3811819851398468,
#   'doppler': -28.75,
#   'dopplerIdx': 396,
#   'peakVal': 4428.0,
#   'range': 219.859375,
#   'rangeIdx': 210,
#   'snr': 1002.0},
#  {'angle': 4.2037353515625,
#   'doppler': 12.921875,
#   'dopplerIdx': 270,
#   'peakVal': 4494.0,
#   'range': 124.3125,
#   'rangeIdx': 119,
#   'snr': 930.0},
#  {'angle': -0.6609584093093872,
#   'doppler': 39.78125,
#   'dopplerIdx': 8,
#   'peakVal': 4506.0,
#   'range': 220.75,
#   'rangeIdx': 211,
#   'snr': 1050.0},
#  {'angle': -0.7448940873146057,
#   'doppler': 39.78125,
#   'dopplerIdx': 9,
#   'peakVal': 4752.0,
#   'range': 221.015625,
#   'rangeIdx': 211,
#   'snr': 1296.0},
#  {'angle': 0.8183391094207764,
#   'doppler': -26.9375,
#   'dopplerIdx': 320,
#   'peakVal': 4464.0,
#   'range': 10.671875,
#   'rangeIdx': 10,
#   'snr': 1158.0},
#  {'angle': -0.8568108677864075,
#   'doppler': 39.859375,
#   'dopplerIdx': 11,
#   'peakVal': 4638.0,
#   'range': 220.90625,
#   'rangeIdx': 211,
#   'snr': 1182.0},
#  {'angle': -1.8782559633255005,
#   'doppler': 26.828125,
#   'dopplerIdx': 136,
#   'peakVal': 4104.0,
#   'range': 75.546875,
#   'rangeIdx': 73,
#   'snr': 780.0},
#  {'angle': 0.3881762623786926,
#   'doppler': -29.40625,
#   'dopplerIdx': 387,
#   'peakVal': 4434.0,
#   'range': 219.484375,
#   'rangeIdx': 211,
#   'snr': 978.0},
#  {'angle': 0.45811930298805237,
#   'doppler': -29.421875,
#   'dopplerIdx': 388,
#   'peakVal': 4434.0,
#   'range': 219.578125,
#   'rangeIdx': 211,
#   'snr': 984.0},
#  {'angle': 0.552543580532074,
#   'doppler': -29.296875,
#   'dopplerIdx': 389,
#   'peakVal': 4578.0,
#   'range': 219.640625,
#   'rangeIdx': 211,
#   'snr': 1122.0},
#  {'angle': 0.5875158309936523,
#   'doppler': -29.21875,
#   'dopplerIdx': 390,
#   'peakVal': 4692.0,
#   'range': 219.53125,
#   'rangeIdx': 211,
#   'snr': 1242.0},
#  {'angle': 2.161694049835205,
#   'doppler': -0.453125,
#   'dopplerIdx': 24,
#   'peakVal': 3864.0,
#   'range': 5.296875,
#   'rangeIdx': 5,
#   'snr': 720.0},
#  {'angle': 4.291403293609619,
#   'doppler': 28.953125,
#   'dopplerIdx': 444,
#   'peakVal': 4380.0,
#   'range': 129.640625,
#   'rangeIdx': 123,
#   'snr': 810.0},
#  {'angle': 4.7755126953125,
#   'doppler': -69.0625,
#   'dopplerIdx': 334,
#   'peakVal': 4404.0,
#   'range': 181.703125,
#   'rangeIdx': 173,
#   'snr': 822.0},
#  {'angle': 12.216653823852539,
#   'doppler': -26.796875,
#   'dopplerIdx': 322,
#   'peakVal': 4374.0,
#   'range': 10.625,
#   'rangeIdx': 10,
#   'snr': 1068.0},
#  {'angle': 4.09854793548584,
#   'doppler': 28.984375,
#   'dopplerIdx': 446,
#   'peakVal': 4464.0,
#   'range': 129.390625,
#   'rangeIdx': 123,
#   'snr': 894.0},
#  {'angle': 12.177297592163086,
#   'doppler': -26.859375,
#   'dopplerIdx': 323,
#   'peakVal': 4128.0,
#   'range': 10.109375,
#   'rangeIdx': 10,
#   'snr': 828.0},
#  {'angle': 4.452736854553223,
#   'doppler': 28.90625,
#   'dopplerIdx': 444,
#   'peakVal': 4434.0,
#   'range': 129.65625,
#   'rangeIdx': 124,
#   'snr': 924.0},
#  {'angle': 4.803587436676025,
#   'doppler': -69.015625,
#   'dopplerIdx': 334,
#   'peakVal': 4398.0,
#   'range': 181.703125,
#   'rangeIdx': 174,
#   'snr': 870.0},
#  {'angle': 4.329979419708252,
#   'doppler': 28.90625,
#   'dopplerIdx': 445,
#   'peakVal': 4428.0,
#   'range': 129.40625,
#   'rangeIdx': 124,
#   'snr': 918.0},
#  {'angle': 4.2598419189453125,
#   'doppler': 28.96875,
#   'dopplerIdx': 446,
#   'peakVal': 4320.0,
#   'range': 129.375,
#   'rangeIdx': 124,
#   'snr': 810.0},
#  {'angle': 6.085824966430664,
#   'doppler': -55.015625,
#   'dopplerIdx': 464,
#   'peakVal': 4668.0,
#   'range': 182.03125,
#   'rangeIdx': 174,
#   'snr': 1140.0},
#  {'angle': 6.117477893829346,
#   'doppler': -43.75,
#   'dopplerIdx': 66,
#   'peakVal': 4248.0,
#   'range': 183.359375,
#   'rangeIdx': 175,
#   'snr': 780.0},
#  {'angle': -0.5105770826339722,
#   'doppler': 0.5,
#   'dopplerIdx': 203,
#   'peakVal': 4872.0,
#   'range': 228.0625,
#   'rangeIdx': 218,
#   'snr': 1266.0},
#  {'angle': -0.7204127311706543,
#   'doppler': 0.40625,
#   'dopplerIdx': 204,
#   'peakVal': 4704.0,
#   'range': 228.0625,
#   'rangeIdx': 218,
#   'snr': 1098.0},
#  {'angle': 6.328545093536377,
#   'doppler': 27.5,
#   'dopplerIdx': 204,
#   'peakVal': 4260.0,
#   'range': 182.828125,
#   'rangeIdx': 175,
#   'snr': 792.0},
#  {'angle': 5.811577320098877,
#   'doppler': -27.4375,
#   'dopplerIdx': 210,
#   'peakVal': 4536.0,
#   'range': 183.328125,
#   'rangeIdx': 175,
#   'snr': 1068.0},
#  {'angle': 6.156167030334473,
#   'doppler': -27.375,
#   'dopplerIdx': 211,
#   'peakVal': 4380.0,
#   'range': 183.234375,
#   'rangeIdx': 175,
#   'snr': 912.0},
#  {'angle': 0.7903599143028259,
#   'doppler': -26.921875,
#   'dopplerIdx': 320,
#   'peakVal': 4044.0,
#   'range': 9.78125,
#   'rangeIdx': 9,
#   'snr': 816.0},
#  {'angle': -1.276531457901001,
#   'doppler': -68.484375,
#   'dopplerIdx': 81,
#   'peakVal': 4326.0,
#   'range': 229.6875,
#   'rangeIdx': 219,
#   'snr': 792.0},
#  {'angle': 0.33571937680244446,
#   'doppler': -67.921875,
#   'dopplerIdx': 86,
#   'peakVal': 4326.0,
#   'range': 229.28125,
#   'rangeIdx': 219,
#   'snr': 792.0},
#  {'angle': 0.46861085295677185,
#   'doppler': -68.015625,
#   'dopplerIdx': 87,
#   'peakVal': 4374.0,
#   'range': 229.25,
#   'rangeIdx': 219,
#   'snr': 840.0},
#  {'angle': 4.305430889129639,
#   'doppler': -29.171875,
#   'dopplerIdx': 311,
#   'peakVal': 4362.0,
#   'range': 108.828125,
#   'rangeIdx': 104,
#   'snr': 930.0},
#  {'angle': 0.6504665613174438,
#   'doppler': -67.5625,
#   'dopplerIdx': 89,
#   'peakVal': 4428.0,
#   'range': 229.015625,
#   'rangeIdx': 219,
#   'snr': 894.0},
#  {'angle': 4.382587432861328,
#   'doppler': 28.859375,
#   'dopplerIdx': 464,
#   'peakVal': 4284.0,
#   'range': 132.71875,
#   'rangeIdx': 126,
#   'snr': 876.0},
#  {'angle': -0.18534433841705322,
#   'doppler': 0.109375,
#   'dopplerIdx': 201,
#   'peakVal': 4458.0,
#   'range': 230.15625,
#   'rangeIdx': 219,
#   'snr': 918.0},
#  {'angle': 4.26334810256958,
#   'doppler': -29.265625,
#   'dopplerIdx': 312,
#   'peakVal': 4434.0,
#   'range': 108.84375,
#   'rangeIdx': 104,
#   'snr': 996.0},
#  {'angle': -0.6224883198738098,
#   'doppler': 0.6875,
#   'dopplerIdx': 204,
#   'peakVal': 4950.0,
#   'range': 229.640625,
#   'rangeIdx': 219,
#   'snr': 1410.0},
#  {'angle': -0.7623808979988098,
#   'doppler': 0.546875,
#   'dopplerIdx': 205,
#   'peakVal': 4794.0,
#   'range': 229.140625,
#   'rangeIdx': 219,
#   'snr': 1254.0},
#  {'angle': -1.000209093093872,
#   'doppler': 0.78125,
#   'dopplerIdx': 206,
#   'peakVal': 4416.0,
#   'range': 229.09375,
#   'rangeIdx': 219,
#   'snr': 882.0},
#  {'angle': 0.32173091173171997,
#   'doppler': 0.34375,
#   'dopplerIdx': 202,
#   'peakVal': 4524.0,
#   'range': 232.15625,
#   'rangeIdx': 220,
#   'snr': 972.0},
#  {'angle': -0.6364774107933044,
#   'doppler': 0.46875,
#   'dopplerIdx': 205,
#   'peakVal': 4404.0,
#   'range': 228.6875,
#   'rangeIdx': 220,
#   'snr': 852.0},
#  {'angle': -0.5420519113540649,
#   'doppler': 13.1875,
#   'dopplerIdx': 330,
#   'peakVal': 4500.0,
#   'range': 230.734375,
#   'rangeIdx': 220,
#   'snr': 948.0},
#  {'angle': 4.438706874847412,
#   'doppler': 28.96875,
#   'dopplerIdx': 464,
#   'peakVal': 4284.0,
#   'range': 132.71875,
#   'rangeIdx': 127,
#   'snr': 948.0},
#  {'angle': 4.2563347816467285,
#   'doppler': -28.921875,
#   'dopplerIdx': 313,
#   'peakVal': 4590.0,
#   'range': 108.8125,
#   'rangeIdx': 104,
#   'snr': 1158.0},
#  {'angle': -1.4199504852294922,
#   'doppler': -27.703125,
#   'dopplerIdx': 462,
#   'peakVal': 4386.0,
#   'range': 231.1875,
#   'rangeIdx': 220,
#   'snr': 834.0},
#  {'angle': 6.346138000488281,
#   'doppler': 14.0,
#   'dopplerIdx': 87,
#   'peakVal': 4344.0,
#   'range': 184.015625,
#   'rangeIdx': 176,
#   'snr': 786.0},
#  {'angle': 5.8396992683410645,
#   'doppler': 29.140625,
#   'dopplerIdx': 466,
#   'peakVal': 4236.0,
#   'range': 133.015625,
#   'rangeIdx': 127,
#   'snr': 894.0},
#  {'angle': 5.259964466094971,
#   'doppler': -56.296875,
#   'dopplerIdx': 463,
#   'peakVal': 4914.0,
#   'range': 184.140625,
#   'rangeIdx': 176,
#   'snr': 1356.0},
#  {'angle': -0.21332095563411713,
#   'doppler': 13.171875,
#   'dopplerIdx': 329,
#   'peakVal': 4512.0,
#   'range': 230.953125,
#   'rangeIdx': 221,
#   'snr': 882.0},
#  {'angle': -0.15037362277507782,
#   'doppler': 13.1875,
#   'dopplerIdx': 330,
#   'peakVal': 4698.0,
#   'range': 230.6875,
#   'rangeIdx': 221,
#   'snr': 1068.0},
#  {'angle': 5.81509256362915,
#   'doppler': -56.296875,
#   'dopplerIdx': 465,
#   'peakVal': 4710.0,
#   'range': 184.140625,
#   'rangeIdx': 176,
#   'snr': 1152.0},
#  {'angle': -0.12939120829105377,
#   'doppler': 13.390625,
#   'dopplerIdx': 332,
#   'peakVal': 4470.0,
#   'range': 231.234375,
#   'rangeIdx': 221,
#   'snr': 834.0},
#  {'angle': -7.487509727478027,
#   'doppler': 29.375,
#   'dopplerIdx': 326,
#   'peakVal': 4230.0,
#   'range': 10.3125,
#   'rangeIdx': 10,
#   'snr': 930.0},
#  {'angle': 5.639362335205078,
#   'doppler': 29.328125,
#   'dopplerIdx': 468,
#   'peakVal': 4260.0,
#   'range': 133.65625,
#   'rangeIdx': 127,
#   'snr': 924.0},
#  {'angle': 5.948684215545654,
#   'doppler': 26.09375,
#   'dopplerIdx': 202,
#   'peakVal': 4548.0,
#   'range': 185.0625,
#   'rangeIdx': 177,
#   'snr': 840.0},
#  {'angle': 4.2773756980896,
#   'doppler': -28.9375,
#   'dopplerIdx': 315,
#   'peakVal': 4548.0,
#   'range': 108.75,
#   'rangeIdx': 104,
#   'snr': 1116.0},
#  {'angle': 5.987361431121826,
#   'doppler': 26.09375,
#   'dopplerIdx': 204,
#   'peakVal': 4572.0,
#   'range': 184.59375,
#   'rangeIdx': 177,
#   'snr': 864.0},
#  {'angle': 6.033074378967285,
#   'doppler': 27.3125,
#   'dopplerIdx': 214,
#   'peakVal': 4596.0,
#   'range': 185.03125,
#   'rangeIdx': 177,
#   'snr': 888.0},
#  {'angle': 4.305430889129639,
#   'doppler': -28.84375,
#   'dopplerIdx': 316,
#   'peakVal': 4326.0,
#   'range': 109.03125,
#   'rangeIdx': 104,
#   'snr': 888.0},
#  {'angle': 5.924072742462158,
#   'doppler': 27.5625,
#   'dopplerIdx': 216,
#   'peakVal': 4554.0,
#   'range': 185.15625,
#   'rangeIdx': 177,
#   'snr': 846.0},
#  {'angle': 6.0014262199401855,
#   'doppler': 27.5,
#   'dopplerIdx': 217,
#   'peakVal': 4536.0,
#   'range': 185.140625,
#   'rangeIdx': 177,
#   'snr': 834.0},
#  {'angle': 5.723706245422363,
#   'doppler': 29.34375,
#   'dopplerIdx': 468,
#   'peakVal': 4194.0,
#   'range': 133.671875,
#   'rangeIdx': 128,
#   'snr': 864.0},
#  {'angle': -2.9143049716949463,
#   'doppler': -29.0,
#   'dopplerIdx': 505,
#   'peakVal': 4212.0,
#   'range': 144.484375,
#   'rangeIdx': 138,
#   'snr': 846.0},
#  {'angle': 4.494830131530762,
#   'doppler': -16.671875,
#   'dopplerIdx': 327,
#   'peakVal': 4524.0,
#   'range': 185.53125,
#   'rangeIdx': 177,
#   'snr': 816.0},
#  {'angle': 5.874853134155273,
#   'doppler': -16.671875,
#   'dopplerIdx': 328,
#   'peakVal': 4494.0,
#   'range': 186.578125,
#   'rangeIdx': 177,
#   'snr': 792.0},
#  {'angle': 4.27036190032959,
#   'doppler': -29.171875,
#   'dopplerIdx': 311,
#   'peakVal': 4230.0,
#   'range': 108.71875,
#   'rangeIdx': 105,
#   'snr': 780.0},
#  {'angle': -2.7462410926818848,
#   'doppler': -29.265625,
#   'dopplerIdx': 503,
#   'peakVal': 4272.0,
#   'range': 145.0,
#   'rangeIdx': 139,
#   'snr': 966.0},
#  {'angle': 5.836183547973633,
#   'doppler': -16.5625,
#   'dopplerIdx': 329,
#   'peakVal': 4740.0,
#   'range': 186.40625,
#   'rangeIdx': 178,
#   'snr': 930.0},
#  {'angle': 4.214255332946777,
#   'doppler': -29.296875,
#   'dopplerIdx': 312,
#   'peakVal': 4314.0,
#   'range': 108.765625,
#   'rangeIdx': 105,
#   'snr': 864.0},
#  {'angle': -2.8757879734039307,
#   'doppler': -28.984375,
#   'dopplerIdx': 505,
#   'peakVal': 4188.0,
#   'range': 144.484375,
#   'rangeIdx': 139,
#   'snr': 882.0},
#  {'angle': 4.2598419189453125,
#   'doppler': -28.9375,
#   'dopplerIdx': 313,
#   'peakVal': 4476.0,
#   'range': 108.8125,
#   'rangeIdx': 105,
#   'snr': 1026.0},
#  {'angle': 4.284389495849609,
#   'doppler': -28.9375,
#   'dopplerIdx': 314,
#   'peakVal': 4518.0,
#   'range': 108.609375,
#   'rangeIdx': 105,
#   'snr': 1068.0},
#  {'angle': -0.209823876619339,
#   'doppler': 29.1875,
#   'dopplerIdx': 10,
#   'peakVal': 4470.0,
#   'range': 240.484375,
#   'rangeIdx': 229,
#   'snr': 954.0},
#  {'angle': -0.20632679760456085,
#   'doppler': 29.125,
#   'dopplerIdx': 11,
#   'peakVal': 4710.0,
#   'range': 239.921875,
#   'rangeIdx': 229,
#   'snr': 1194.0},
#  {'angle': -0.1573677659034729,
#   'doppler': 29.296875,
#   'dopplerIdx': 12,
#   'peakVal': 4866.0,
#   'range': 239.890625,
#   'rangeIdx': 229,
#   'snr': 1350.0},
#  {'angle': 6.138580799102783,
#   'doppler': 29.578125,
#   'dopplerIdx': 260,
#   'peakVal': 4530.0,
#   'range': 189.84375,
#   'rangeIdx': 181,
#   'snr': 864.0},
#  {'angle': 1.1541067361831665,
#   'doppler': 29.421875,
#   'dopplerIdx': 14,
#   'peakVal': 4752.0,
#   'range': 239.859375,
#   'rangeIdx': 229,
#   'snr': 1236.0},
#  {'angle': 0.8393236994743347,
#   'doppler': 29.53125,
#   'dopplerIdx': 15,
#   'peakVal': 4518.0,
#   'range': 240.03125,
#   'rangeIdx': 229,
#   'snr': 1002.0},
#  {'angle': 0.5805213451385498,
#   'doppler': 29.5625,
#   'dopplerIdx': 16,
#   'peakVal': 4332.0,
#   'range': 239.96875,
#   'rangeIdx': 229,
#   'snr': 810.0},
#  {'angle': 4.301923751831055,
#   'doppler': -28.828125,
#   'dopplerIdx': 315,
#   'peakVal': 4422.0,
#   'range': 108.75,
#   'rangeIdx': 105,
#   'snr': 972.0},
#  {'angle': 0.5315603017807007,
#   'doppler': 17.9375,
#   'dopplerIdx': 414,
#   'peakVal': 4446.0,
#   'range': 238.671875,
#   'rangeIdx': 229,
#   'snr': 930.0},
#  {'angle': 0.18184725940227509,
#   'doppler': 29.0625,
#   'dopplerIdx': 10,
#   'peakVal': 4470.0,
#   'range': 240.484375,
#   'rangeIdx': 230,
#   'snr': 924.0},
#  {'angle': 0.0839293971657753,
#   'doppler': 29.09375,
#   'dopplerIdx': 11,
#   'peakVal': 4506.0,
#   'range': 240.234375,
#   'rangeIdx': 230,
#   'snr': 960.0},
#  {'angle': 0.01398822758346796,
#   'doppler': 29.15625,
#   'dopplerIdx': 12,
#   'peakVal': 4428.0,
#   'range': 239.578125,
#   'rangeIdx': 230,
#   'snr': 882.0},
#  {'angle': 4.340501308441162,
#   'doppler': -28.78125,
#   'dopplerIdx': 316,
#   'peakVal': 4362.0,
#   'range': 109.0,
#   'rangeIdx': 105,
#   'snr': 912.0},
#  {'angle': 0.0,
#   'doppler': 42.6875,
#   'dopplerIdx': 142,
#   'peakVal': 4524.0,
#   'range': 240.84375,
#   'rangeIdx': 230,
#   'snr': 978.0},
#  {'angle': 5.7623677253723145,
#   'doppler': -29.171875,
#   'dopplerIdx': 332,
#   'peakVal': 4326.0,
#   'range': 112.59375,
#   'rangeIdx': 107,
#   'snr': 948.0},
#  {'angle': 5.7623677253723145,
#   'doppler': -29.078125,
#   'dopplerIdx': 333,
#   'peakVal': 4224.0,
#   'range': 111.546875,
#   'rangeIdx': 107,
#   'snr': 852.0},
#  {'angle': 0.7623808979988098,
#   'doppler': -26.921875,
#   'dopplerIdx': 321,
#   'peakVal': 4176.0,
#   'range': 11.609375,
#   'rangeIdx': 9,
#   'snr': 942.0},
#  {'angle': 5.656932830810547,
#   'doppler': -29.40625,
#   'dopplerIdx': 329,
#   'peakVal': 4254.0,
#   'range': 112.390625,
#   'rangeIdx': 108,
#   'snr': 816.0},
#  {'angle': 5.456659317016602,
#   'doppler': -29.40625,
#   'dopplerIdx': 330,
#   'peakVal': 4386.0,
#   'range': 112.546875,
#   'rangeIdx': 108,
#   'snr': 948.0},
#  {'angle': 5.7483086585998535,
#   'doppler': -29.234375,
#   'dopplerIdx': 139,
#   'peakVal': 4674.0,
#   'range': 172.859375,
#   'rangeIdx': 165,
#   'snr': 1176.0},
#  {'angle': 6.434110641479492,
#   'doppler': 58.203125,
#   'dopplerIdx': 20,
#   'peakVal': 4356.0,
#   'range': 191.0,
#   'rangeIdx': 183,
#   'snr': 792.0},
#  {'angle': 5.720191478729248,
#   'doppler': -29.21875,
#   'dopplerIdx': 331,
#   'peakVal': 4548.0,
#   'range': 112.65625,
#   'rangeIdx': 108,
#   'snr': 1116.0}]

# %%
plt.imshow(np.array([item['data'] for item in rd_data.rangeDoppler]).reshape(512, -1).T)
